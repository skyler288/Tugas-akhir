# %% [markdown]
# # 1. Install and Import Dependencies

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# ^C

# %%
import torch;
torch.__version__
# Out:
# '2.2.1+cu118'

# %%
# !pip install --upgrade ultralytics
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.5736, 0.4467, 0.3297],
#         [0.5403, 0.7835, 0.7570],
#         [0.6344, 0.7199, 0.1600],
#         [0.7765, 0.7041, 0.3481],
#         [0.1796, 0.9081, 0.0384]])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
from ultralytics import YOLO
from IPython.display import display, Image

# %% [markdown]
# # 2. Load Model

# %%
model = torch.hub.load('.ipynb_checkpoints/yolov5/models', 'yolov5s')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 model = torch.hub.load('.ipynb_checkpoints/yolov5/models', 'yolov5s')
#
# File c:\Users\Yosua\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\hub.py:563, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     559     raise ValueError(
#     560         f'Unknown source: "{source}". Allowed values: "github" | "local".')
#     562 if source == 'github':
# --> 563     repo_or_dir = _get_cache_or_reload(repo_or_dir, force_reload, trust_repo, "load",
#     564                                        verbose=verbose, skip_validation=skip_validation)
#     566 model = _load_local(repo_or_dir, model, *args, **kwargs)
#     567 return model
#
# ...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %% [markdown]
# # 3. Make Detections with Images

# %%
img = 'data\images\Green_Traffic_Light_005.jpg'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 4928x3264 4 persons, 3 cars, 4 traffic lights
# Speed: 190.4ms pre-process, 38.9ms inference, 91.8ms NMS per image at shape (1, 3, 640, 448)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()
# Out:
# [array([[[216, 215, 211],
#          [217, 216, 212],
#          [215, 214, 210],
#          ...,
#          [147, 145, 133],
#          [148, 146, 134],
#          [150, 148, 136]],
#
#         [[215, 214, 210],
#          [216, 215, 211],
#          [213, 212, 208],
#          ...,
#          [148, 146, 134],
#          [149, 147, 135],
#          [150, 148, 136]],
#
#         [[214, 213, 209],
#          [213, 212, 208],
#          [209, 208, 204],
#          ...,
#          [150, 148, 135],
#          [150, 148, 135],
#          [150, 148, 135]],
#
#         ...,
#
#         [[163, 166, 171],
#          [163, 166, 171],
#          [162, 165, 170],
#          ...,
#          [145, 144, 142],
#          [145, 144, 142],
#          [147, 146, 144]],
#
#         [[162, 165, 170],
#          [162, 165, 170],
#          [162, 165, 170],
#          ...,
#          [145, 144, 142],
#          [143, 142, 140],
#          [145, 144, 142]],
#
#         [[161, 164, 169],
# ...

# %% [markdown]
# # 4. Real Time Detections

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 10
#       6     results = model(frame)
#       8     cv2.imshow('YOLO', np.squeeze(results.render()))
# ---> 10     if cv2.waitKey(10) & 0xFF == ord('q'):
#      11         break
#      12 cap.release()
#
# KeyboardInterrupt:

# %% [markdown]
# # 5. Train from scratch

# %%
import uuid   # Unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['Green_Light', 'Red_Light','Yellow_Light', 'Speed_Limit']
number_imgs = 190

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
        cv2.imwrite(imgname, frame)
        
        # Render to the screen
        cv2.imshow('Image Collection', frame)
        
        # 2 second delay between captures
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1())+'.jpg'))

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)

# %%
#!git clone https://github.com/tzutalin/labelImg
# Out:
# Cloning into 'labelImg'...
# error: 5525 bytes of body are still expected
# fetch-pack: unexpected disconnect while reading sideband packet
# fatal: early EOF
# fatal: fetch-pack: invalid index-pack output

# %%
# !pip install pyqt5 lxml --upgrade
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !cd labelImg && pyrcc5 -o Users/Yosua/Desktop/Kuliah/YOLO-Drowsiness-Detection-main/.ipynb_checkpoints/labelimg/libs/resources.py resources.qrc
# Out:
# Unable to open Users/Yosua/Desktop/Kuliah/YOLO-Drowsiness-Detection-main/.ipynb_checkpoints/labelimg/libs/resources.py for writing

# %%
import os

def rename_files(folder_path, prefix, start_index, end_index):
    # Get a list of all files in the folder
    files = os.listdir(folder_path)
    
    # Filter out only JPG files
    jpg_files = [file for file in files if file.endswith('.jpg')]

    # Iterate over the JPG files and rename them
    for i, filename in enumerate(jpg_files, start=start_index):
        new_filename = f"{prefix}_{str(i).zfill(3)}.jpg"
        os.rename(os.path.join(folder_path, filename), os.path.join(folder_path, new_filename))
        print(f"Renamed {filename} to {new_filename}")

# Provide the folder path and desired parameters for renaming
folder_path = "C:\\Users\\Yosua\\Downloads\\Green_Light"
prefix = "Green_Traffic_Light"
start_index = 1
end_index = 22

rename_files(folder_path, prefix, start_index, end_index)
# Out:
# Renamed carlos-alberto-gomez-iniguez-jqiAU_JQGyk-unsplash.jpg to Green_Traffic_Light_001.jpg
# Renamed chase-charaba-uRHzV3ca2fk-unsplash.jpg to Green_Traffic_Light_002.jpg
# Renamed daniel-kim-5fkbaBTJuBg-unsplash.jpg to Green_Traffic_Light_003.jpg
# Renamed david-watkis-LwRUp8vJJI8-unsplash.jpg to Green_Traffic_Light_004.jpg
# Renamed dmitriy-nushtaev-5BaKKlPwBpI-unsplash.jpg to Green_Traffic_Light_005.jpg
# Renamed eliobed-suarez-PN-YnI5stdQ-unsplash.jpg to Green_Traffic_Light_006.jpg
# Renamed ian-delashmutt-h3X6b2c4fa8-unsplash.jpg to Green_Traffic_Light_007.jpg
# Renamed ken-wyatt-Bt02pzZSlsk-unsplash.jpg to Green_Traffic_Light_008.jpg
# Renamed patrick-tomasso-LczBrW5Z6FU-unsplash.jpg to Green_Traffic_Light_009.jpg
# Renamed pawel-czerwinski--Y0qPpeO5Us-unsplash.jpg to Green_Traffic_Light_010.jpg
# Renamed pexels-ekaterina-belinskaya-4744689.jpg to Green_Traffic_Light_011.jpg
# Renamed S__42983546.jpg to Green_Traffic_Light_012.jpg
# ...

# %%
# !cd yolov5

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 100 --data dataset.yml --weights yolov5s.pt --workers 2
# Out:
# WARNING:tensorflow:From c:\Users\Yosua\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# ...

# %% [markdown]
# # 6. Load Custom Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp2/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\Yosua/.cache\torch\hub\master.zip
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp2/weights/last.pt', force_reload=True)
#
# File c:\Users\Yosua\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\hub.py:563, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     559     raise ValueError(
#     560         f'Unknown source: "{source}". Allowed values: "github" | "local".')
#     562 if source == 'github':
# --> 563     repo_or_dir = _get_cache_or_reload(repo_or_dir, force_reload, trust_repo, "load",
#     564                                        verbose=verbose, skip_validation=skip_validation)
# ...

# %%
img = os.path.join('data', 'images', '1709455815090.jpg')

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 1477x1108 (no detections)
# Speed: 32.4ms pre-process, 97.3ms inference, 0.0ms NMS per image at shape (1, 3, 640, 480)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\Yosua\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Yosua\AppData\Local\Temp\ipykernel_29420\999695382.py", line 6, in <module>
#     results = model(frame)
#               ^^^^^^^^^^^^
#   File "c:\Users\Yosua\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Yosua\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
